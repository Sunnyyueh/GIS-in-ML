# %%
import geopandas as gpd
import pandas as pd
housing_shp=gpd.read_file("data/california_housing.shp")

# %%
housing_shp.plot()
# Out:
# <AxesSubplot:>

# %%
housing_shp.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'total_room'}>,
#         <AxesSubplot:title={'center':'total_bedr'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_inc'}>,
#         <AxesSubplot:title={'center':'house_age'}>],
#        [<AxesSubplot:title={'center':'median_val'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
housing_shp["house_age"].max()
housing_shp_cleaned = housing_shp[housing_shp["house_age"] < 52]

# %%
housing_shp_cleaned["median_val"].max()
housing_shp_cleaned = housing_shp_cleaned[housing_shp_cleaned["median_val"] < 500001.0]

# %%
housing_shp_cleaned.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'total_room'}>,
#         <AxesSubplot:title={'center':'total_bedr'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_inc'}>,
#         <AxesSubplot:title={'center':'house_age'}>],
#        [<AxesSubplot:title={'center':'median_val'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
housing_shp_cleaned["ocean_prox"].unique()
housing_shp_cleaned = pd.get_dummies(housing_shp_cleaned)

# %%
training_data = housing_shp_cleaned.sample(frac=0.8, random_state=42)
test_data = housing_shp_cleaned.drop(training_data.index)

# %%
training_X=training_data[training_data.columns.drop(['median_val','geometry'])]
training_y = training_data["median_val"]

# %%
training_X.head()
# Out:
#        total_room  total_bedr  population  households  median_inc  house_age  \
# 12869      4842.0       935.0      2857.0       907.0     39318.0        7.0
# 8961        593.0       137.0       371.0       132.0     46932.0       40.0
# 20309      1612.0       334.0      1431.0       335.0     48125.0       22.0
# 17392      2121.0       445.0      2211.0       463.0     40603.0       21.0
# 6961       3531.0       754.0      1613.0       697.0     32359.0       36.0
#
#        ocean_prox_<1H OCEAN  ocean_prox_INLAND  ocean_prox_ISLAND  \
# 12869                     0                  1                  0
# 8961                      1                  0                  0
# 20309                     0                  0                  0
# 17392                     1                  0                  0
# 6961                      1                  0                  0
#
#        ocean_prox_NEAR BAY  ocean_prox_NEAR OCEAN
# 12869                    0                      0
# 8961                     0                      0
# 20309                    0                      1
# 17392                    0                      0
# 6961                     0                      0

# %%
def standardize_data(data, stats):
    return (data - stats['mean'])/stats['std']

# %%
training_stats = training_X.describe().transpose()
training_stats
# Out:
#                          count          mean           std     min       25%  \
# total_room             14858.0   2668.450128   2253.243630     2.0   1444.00
# total_bedr             14858.0    541.619262    435.084160     0.0    294.00
# population             14858.0   1469.974896   1183.121367     3.0    805.25
# households             14858.0    508.484386    394.538475     2.0    282.00
# median_inc             14858.0  36912.562996  15674.248967  4999.0  25386.25
# house_age              14858.0     26.971934     11.469346     1.0     17.00
# ocean_prox_<1H OCEAN   14858.0      0.446965      0.497196     0.0      0.00
# ocean_prox_INLAND      14858.0      0.341163      0.474116     0.0      0.00
# ocean_prox_ISLAND      14858.0      0.000135      0.011602     0.0      0.00
# ocean_prox_NEAR BAY    14858.0      0.085880      0.280196     0.0      0.00
# ocean_prox_NEAR OCEAN  14858.0      0.125858      0.331701     0.0      0.00
#
#                            50%       75%       max
# total_room              2137.0   3192.75   39320.0
# total_bedr               436.0    656.00    6445.0
# population              1201.0   1777.00   35682.0
# households               415.0    615.00    6082.0
# median_inc             34643.0  46111.00  150001.0
# house_age                 27.0     36.00      51.0
# ocean_prox_<1H OCEAN       0.0      1.00       1.0
# ocean_prox_INLAND          0.0      1.00       1.0
# ocean_prox_ISLAND          0.0      0.00       1.0
# ocean_prox_NEAR BAY        0.0      0.00       1.0
# ocean_prox_NEAR OCEAN      0.0      0.00       1.0

# %%
training_X_std = standardize_data(training_X, training_stats)
training_X_std.head()

# %%
test_X=test_data[test_data.columns.drop(['median_val','geometry'])]
test_y = test_data["median_val"]
test_X_std = standardize_data(test_X, training_stats)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

# %%
linear_model = LinearRegression()
linear_model.fit(training_X_std, training_y)
# Out:
# LinearRegression()

# %%
test_y_pred = linear_model.predict(test_X_std)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,6))
plt.scatter(test_y,test_y_pred,s=15, c='blue')
plt.xlabel("Observed values")
plt.ylabel("Predicted values")
plt.xlim([0, 500000])
plt.ylim([0, 500000])
plt.plot([0,500000],[0,500000],'r--')

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = mean_squared_error(test_y,test_y_pred,squared=False)
rmse
# Out:
# 59767.30932360194

# %%
test_y
# Out:
# 21       159800.0
# 25       107500.0
# 28       108900.0
# 32       110400.0
# 34       109700.0
#            ...
# 20626     93800.0
# 20630    112000.0
# 20632    115600.0
# 20637     92300.0
# 20639     89400.0
# Name: median_val, Length: 3714, dtype: float64
